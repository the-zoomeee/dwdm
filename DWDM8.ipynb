# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline 
import numpy as np
customer_data = pd.read_csv('hierar.csv')

# %%
# Check the shape and preview the data
print(customer_data.shape)
print(customer_data.head())
# Out:
# (50, 5)
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   58                  71                      68
# 1           2  Female   44                  77                      87
# 2           3  Female   48                  71                      61
# 3           4    Male   23                  63                      94
# 4           5  Female   33                  32                      42

# %%
data = customer_data.iloc[:, 3:5].values
data
# Out:
# array([[ 71,  68],
#        [ 77,  87],
#        [ 71,  61],
#        [ 63,  94],
#        [ 32,  42],
#        [ 72,  41],
#        [ 24,  61],
#        [ 77,  82],
#        [ 94,  52],
#        [ 93,  41],
#        [ 48,  60],
#        [ 19,  95],
#        [ 31,  30],
#        [ 86,  98],
#        [ 77,  95],
#        [ 38,  38],
#        [ 22,  89],
#        [ 37,  17],
#        [ 45, 100],
#        [ 95,  40],
#        [ 42,  30],
#        [ 62,  66],
#        [ 26,  24],
#        [ 93,  73],
#        [ 45,   1],
#        [ 49,  88],
#        [ 69,  38],
#        [ 96,  64],
#        [ 50,  27],
#        [ 86,  90],
#        [ 74,  90],
#        [ 52,   7],
#        [ 83,  89],
#        [ 68,  80],
#        [ 28,  42],
#        [ 34,  18],
#        [ 23,  81],
#        [ 96,  44],
#        [ 84,  70],
#        [ 16,  20],
#        [ 44,  23],
#        [ 20,  12],
#        [ 95,  12],
#        [ 55,  34],
#        [ 37,   8],
#        [ 45,  27],
#        [ 34,  49],
#        [ 19,  72],
#        [ 35,  55],
#        [ 89,  97]])

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram (shc.linkage(data, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward') 
labels_=cluster.fit_predict(data)
labels_
# Out:
# array([0, 3, 0, 3, 4, 0, 4, 3, 0, 0, 4, 2, 1, 3, 3, 4, 2, 1, 2, 0, 1, 0,
#        1, 0, 1, 2, 0, 0, 1, 3, 3, 1, 3, 3, 4, 1, 2, 0, 0, 1, 1, 1, 0, 1,
#        1, 1, 4, 2, 4, 3])

# %%
plt.figure(figsize=(10, 7))
plt.scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
